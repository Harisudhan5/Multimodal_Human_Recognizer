# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\koush\anaconda3\envs\main\lib\site-packages (0.10.10)
# Requirement already satisfied: opencv-python in c:\users\koush\anaconda3\envs\main\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pandas in c:\users\koush\anaconda3\envs\main\lib\site-packages (2.2.1)
# Requirement already satisfied: scikit-learn in c:\users\koush\anaconda3\envs\main\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: absl-py in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: jax in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (0.4.24)
# Requirement already satisfied: matplotlib in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (3.8.3)
# Requirement already satisfied: numpy in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\koush\anaconda3\envs\main\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from jax->mediapipe) (6.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: pycparser in c:\users\koush\anaconda3\envs\main\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\koush\anaconda3\envs\main\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.17.0)
# DEPRECATION: neuralplot 0.0.8 has a non-standard dependency specifier matplotlib>=3.1numpy>=1.16. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of neuralplot or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv
# Out:
# WARNING:tensorflow:From c:\Users\koush\anaconda3\envs\main\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Speaking"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0  Laughing  0.544193  0.495133 -1.154361  0.999650  0.574432  0.428493
# 1  Laughing  0.544297  0.495706 -1.328870  0.999623  0.574438  0.428509
# 2  Laughing  0.544564  0.496217 -1.342712  0.999604  0.574510  0.428514
# 3  Laughing  0.544650  0.496255 -1.381453  0.999596  0.574516  0.428280
# 4  Laughing  0.544794  0.495733 -1.345218  0.999610  0.574513  0.427710
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -1.075998  0.999192  0.591813  ... -0.004553   0.0  0.611083  0.413607
# 1 -1.238262  0.999148  0.591987  ... -0.002349   0.0  0.608227  0.414808
# 2 -1.252387  0.999126  0.592305  ... -0.003523   0.0  0.608511  0.414034
# 3 -1.289040  0.999131  0.592446  ... -0.002803   0.0  0.609584  0.412419
# 4 -1.258876  0.999165  0.592520  ... -0.003505   0.0  0.607722  0.415160
#
#        z500  v500      x501      y501      z501  v501
# 0  0.018140   0.0  0.616520  0.408076  0.018878   0.0
# 1  0.020968   0.0  0.613708  0.409203  0.021860   0.0
# 2  0.018812   0.0  0.613956  0.408361  0.019609   0.0
# 3  0.019912   0.0  0.615080  0.406874  0.020669   0.0
# 4  0.018561   0.0  0.613230  0.409692  0.019312   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 1962  Speaking  0.625318  0.403507 -0.784957  0.999847  0.624714  0.345980
# 1963  Speaking  0.624034  0.417071 -0.829295  0.999825  0.626765  0.356017
# 1964  Speaking  0.629264  0.425162 -0.827396  0.999799  0.634303  0.362618
# 1965  Speaking  0.640821  0.428783 -0.827229  0.999764  0.643485  0.366508
# 1966  Speaking  0.643773  0.432153 -0.783843  0.999750  0.647308  0.370136
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# 1962 -0.713241  0.999758  0.633729  ...  0.013506   0.0  0.662534  0.363180
# 1963 -0.757429  0.999728  0.636331  ...  0.008157   0.0  0.669496  0.371010
# 1964 -0.755959  0.999691  0.644056  ...  0.008393   0.0  0.675138  0.374918
# 1965 -0.755226  0.999642  0.651983  ...  0.008176   0.0  0.676596  0.375935
# 1966 -0.712949  0.999626  0.656039  ...  0.007623   0.0  0.682732  0.380455
#
#           z500  v500      x501      y501      z501  v501
# 1962  0.048391   0.0  0.666388  0.359719  0.050658   0.0
# 1963  0.046869   0.0  0.673187  0.366534  0.049476   0.0
# 1964  0.046900   0.0  0.678518  0.370904  0.049395   0.0
# 1965  0.046475   0.0  0.679934  0.372457  0.048796   0.0
# 1966  0.046318   0.0  0.686301  0.376550  0.048688   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Sad']
# Out:
# Empty DataFrame
# Columns: [class, x1, y1, z1, v1, x2, y2, z2, v2, x3, y3, z3, v3, x4, y4, z4, v4, x5, y5, z5, v5, x6, y6, z6, v6, x7, y7, z7, v7, x8, y8, z8, v8, x9, y9, z9, v9, x10, y10, z10, v10, x11, y11, z11, v11, x12, y12, z12, v12, x13, y13, z13, v13, x14, y14, z14, v14, x15, y15, z15, v15, x16, y16, z16, v16, x17, y17, z17, v17, x18, y18, z18, v18, x19, y19, z19, v19, x20, y20, z20, v20, x21, y21, z21, v21, x22, y22, z22, v22, x23, y23, z23, v23, x24, y24, z24, v24, x25, y25, z25, ...]
# Index: []
#
# [0 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 463     Speaking_Phone
# 1868          Speaking
# 1538           Sitting
# 422     Speaking_Phone
# 1016       Using_Phone
#              ...
# 147           Laughing
# 1410           Sitting
# 227           Laughing
# 1185       Using_Phone
# 485     Speaking_Phone
# Name: class, Length: 591, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Speaking_Phone', 'Speaking', 'Sitting', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Laughing', 'Speaking', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Sitting', 'Laughing',
#        'Laughing', 'Sitting', 'Using_Phone', 'Speaking', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Sitting', 'Speaking',
#        'Speaking_Phone', 'Laughing', 'Laughing', 'Laughing',
#        'Using_Phone', 'Laughing', 'Using_Phone', 'Sitting', 'Laughing',
#        'Laughing', 'Sitting', 'Laughing', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Using_Phone', 'Speaking_Phone', 'Laughing', 'Speaking',
#        'Speaking_Phone', 'Sitting', 'Speaking', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Speaking_Phone', 'Speaking',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Sitting', 'Sitting', 'Speaking',
#        'Sitting', 'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Sitting', 'Using_Phone', 'Laughing', 'Sitting', 'Speaking_Phone',
#        'Using_Phone', 'Using_Phone', 'Laughing', 'Laughing', 'Sitting',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Sitting', 'Sitting', 'Speaking',
#        'Using_Phone', 'Using_Phone', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking_Phone', 'Speaking', 'Sitting', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking', 'Speaking',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Speaking_Phone',
#        'Speaking', 'Using_Phone', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Speaking', 'Using_Phone',
#        'Using_Phone', 'Using_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Sitting', 'Laughing', 'Using_Phone',
#        'Sitting', 'Speaking', 'Laughing', 'Speaking_Phone', 'Speaking',
#        'Speaking_Phone', 'Using_Phone', 'Using_Phone', 'Speaking',
#        'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Laughing', 'Sitting',
#        'Laughing', 'Using_Phone', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Sitting', 'Speaking', 'Sitting', 'Laughing',
#        'Sitting', 'Sitting', 'Sitting', 'Sitting', 'Using_Phone',
#        'Sitting', 'Speaking', 'Sitting', 'Speaking_Phone', 'Using_Phone',
#        'Sitting', 'Laughing', 'Using_Phone', 'Sitting', 'Sitting',
#        'Speaking_Phone', 'Speaking', 'Sitting', 'Speaking', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Laughing', 'Speaking',
#        'Laughing', 'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Sitting', 'Using_Phone', 'Speaking',
#        'Laughing', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Laughing', 'Speaking',
#        'Using_Phone', 'Sitting', 'Speaking_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking_Phone', 'Laughing', 'Sitting',
#        'Sitting', 'Speaking', 'Laughing', 'Speaking', 'Laughing',
#        'Sitting', 'Laughing', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Speaking_Phone', 'Sitting', 'Laughing',
#        'Sitting', 'Sitting', 'Speaking_Phone', 'Sitting', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Sitting', 'Sitting', 'Laughing',
#        'Laughing', 'Speaking_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Speaking_Phone', 'Sitting', 'Speaking_Phone', 'Speaking',
#        'Speaking', 'Speaking_Phone', 'Laughing', 'Sitting', 'Speaking',
#        'Using_Phone', 'Speaking_Phone', 'Speaking', 'Sitting', 'Laughing',
#        'Laughing', 'Laughing', 'Laughing', 'Speaking', 'Using_Phone',
#        'Sitting', 'Speaking', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Speaking_Phone', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Laughing', 'Using_Phone', 'Laughing', 'Using_Phone', 'Speaking',
#        'Sitting', 'Speaking_Phone', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone', 'Sitting',
#        'Laughing', 'Using_Phone', 'Laughing', 'Laughing',
#        'Speaking_Phone', 'Using_Phone', 'Laughing', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking', 'Using_Phone',
#        'Sitting', 'Using_Phone', 'Laughing', 'Speaking_Phone', 'Sitting',
#        'Sitting', 'Speaking', 'Speaking', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Speaking_Phone',
#        'Sitting', 'Using_Phone', 'Laughing', 'Speaking_Phone', 'Laughing',
#        'Sitting', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking', 'Using_Phone', 'Speaking_Phone',
#        'Speaking', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Speaking', 'Laughing',
#        'Using_Phone', 'Using_Phone', 'Using_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking_Phone', 'Sitting', 'Speaking', 'Speaking',
#        'Sitting', 'Laughing', 'Laughing', 'Sitting', 'Speaking_Phone',
#        'Speaking', 'Speaking', 'Speaking_Phone', 'Speaking', 'Speaking',
#        'Using_Phone', 'Sitting', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking', 'Laughing', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Speaking', 'Sitting', 'Laughing', 'Sitting', 'Laughing',
#        'Speaking', 'Using_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Using_Phone', 'Speaking',
#        'Sitting', 'Laughing', 'Sitting', 'Using_Phone', 'Laughing',
#        'Sitting', 'Speaking_Phone', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Using_Phone', 'Speaking_Phone', 'Speaking',
#        'Laughing', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Laughing', 'Using_Phone', 'Laughing', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking', 'Laughing', 'Sitting', 'Speaking_Phone', 'Sitting',
#        'Speaking', 'Using_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Sitting', 'Speaking_Phone', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Sitting', 'Sitting', 'Speaking',
#        'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Sitting',
#        'Using_Phone', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Speaking', 'Speaking_Phone', 'Laughing', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking', 'Using_Phone', 'Sitting',
#        'Using_Phone', 'Using_Phone', 'Laughing', 'Using_Phone', 'Sitting',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Laughing', 'Using_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Speaking_Phone', 'Sitting',
#        'Sitting', 'Laughing', 'Speaking', 'Sitting', 'Using_Phone',
#        'Sitting', 'Speaking', 'Speaking', 'Sitting', 'Sitting',
#        'Laughing', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Speaking', 'Sitting', 'Sitting',
#        'Sitting', 'Laughing', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Speaking', 'Sitting', 'Sitting',
#        'Laughing', 'Sitting', 'Laughing', 'Laughing', 'Laughing',
#        'Sitting', 'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking',
#        'Speaking_Phone', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Sitting', 'Speaking', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Using_Phone', 'Speaking', 'Laughing',
#        'Laughing', 'Sitting', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking_Phone', 'Sitting',
#        'Laughing', 'Sitting', 'Laughing', 'Using_Phone', 'Speaking_Phone'],
#       dtype='<U14')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9847715736040609
# rc 1.0
# rf 0.9966159052453468
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Speaking_Phone', 'Speaking', 'Sitting', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Laughing', 'Speaking', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Sitting', 'Laughing',
#        'Laughing', 'Sitting', 'Using_Phone', 'Speaking', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Sitting', 'Speaking',
#        'Speaking_Phone', 'Laughing', 'Laughing', 'Laughing',
#        'Using_Phone', 'Laughing', 'Using_Phone', 'Sitting', 'Laughing',
#        'Laughing', 'Sitting', 'Laughing', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Using_Phone', 'Speaking_Phone', 'Laughing', 'Speaking',
#        'Speaking_Phone', 'Sitting', 'Speaking', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Speaking_Phone', 'Speaking',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Sitting', 'Sitting', 'Speaking',
#        'Sitting', 'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Sitting', 'Using_Phone', 'Laughing', 'Sitting', 'Speaking_Phone',
#        'Using_Phone', 'Using_Phone', 'Laughing', 'Laughing', 'Sitting',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Sitting', 'Sitting', 'Speaking',
#        'Using_Phone', 'Using_Phone', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking_Phone', 'Speaking', 'Sitting', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking', 'Speaking',
#        'Using_Phone', 'Sitting', 'Sitting', 'Speaking_Phone', 'Speaking',
#        'Using_Phone', 'Speaking_Phone', 'Sitting', 'Speaking_Phone',
#        'Using_Phone', 'Speaking', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking_Phone', 'Using_Phone',
#        'Laughing', 'Sitting', 'Laughing', 'Using_Phone', 'Sitting',
#        'Speaking', 'Laughing', 'Speaking_Phone', 'Speaking',
#        'Speaking_Phone', 'Using_Phone', 'Using_Phone', 'Speaking',
#        'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Laughing', 'Sitting',
#        'Laughing', 'Using_Phone', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Sitting', 'Speaking', 'Sitting', 'Laughing',
#        'Sitting', 'Sitting', 'Sitting', 'Sitting', 'Using_Phone',
#        'Sitting', 'Speaking', 'Sitting', 'Speaking_Phone', 'Using_Phone',
#        'Sitting', 'Laughing', 'Using_Phone', 'Sitting', 'Sitting',
#        'Speaking_Phone', 'Speaking', 'Sitting', 'Speaking', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Laughing', 'Speaking',
#        'Laughing', 'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Sitting', 'Using_Phone', 'Speaking',
#        'Laughing', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Laughing', 'Speaking',
#        'Using_Phone', 'Sitting', 'Speaking_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking_Phone', 'Laughing', 'Sitting',
#        'Sitting', 'Speaking', 'Laughing', 'Speaking', 'Laughing',
#        'Sitting', 'Laughing', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Speaking_Phone', 'Sitting', 'Laughing',
#        'Sitting', 'Sitting', 'Speaking_Phone', 'Sitting', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Sitting', 'Sitting', 'Laughing',
#        'Laughing', 'Speaking_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Speaking_Phone', 'Sitting', 'Speaking_Phone', 'Speaking',
#        'Speaking', 'Speaking_Phone', 'Laughing', 'Sitting', 'Speaking',
#        'Using_Phone', 'Speaking_Phone', 'Speaking', 'Sitting', 'Laughing',
#        'Laughing', 'Laughing', 'Laughing', 'Speaking', 'Using_Phone',
#        'Sitting', 'Speaking', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Speaking_Phone', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Laughing', 'Using_Phone', 'Laughing', 'Using_Phone', 'Speaking',
#        'Sitting', 'Speaking_Phone', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone', 'Sitting',
#        'Laughing', 'Using_Phone', 'Laughing', 'Laughing',
#        'Speaking_Phone', 'Using_Phone', 'Laughing', 'Using_Phone',
#        'Sitting', 'Sitting', 'Sitting', 'Using_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking', 'Using_Phone',
#        'Sitting', 'Using_Phone', 'Laughing', 'Speaking_Phone', 'Sitting',
#        'Sitting', 'Speaking', 'Speaking', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Speaking_Phone',
#        'Sitting', 'Using_Phone', 'Laughing', 'Speaking_Phone', 'Laughing',
#        'Sitting', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking', 'Using_Phone', 'Speaking_Phone',
#        'Speaking', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Speaking', 'Laughing',
#        'Using_Phone', 'Using_Phone', 'Using_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking_Phone', 'Sitting', 'Speaking', 'Speaking',
#        'Sitting', 'Laughing', 'Laughing', 'Sitting', 'Speaking_Phone',
#        'Speaking', 'Speaking', 'Speaking_Phone', 'Speaking', 'Speaking',
#        'Using_Phone', 'Sitting', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking', 'Laughing', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Speaking', 'Sitting', 'Laughing', 'Sitting', 'Laughing',
#        'Speaking', 'Using_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Using_Phone', 'Speaking',
#        'Sitting', 'Laughing', 'Sitting', 'Using_Phone', 'Laughing',
#        'Sitting', 'Speaking_Phone', 'Speaking_Phone', 'Sitting',
#        'Speaking_Phone', 'Laughing', 'Using_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Using_Phone', 'Speaking_Phone', 'Speaking',
#        'Laughing', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Laughing', 'Using_Phone', 'Laughing', 'Speaking_Phone',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Speaking_Phone', 'Speaking_Phone',
#        'Speaking', 'Laughing', 'Sitting', 'Speaking_Phone', 'Sitting',
#        'Speaking', 'Using_Phone', 'Sitting', 'Laughing', 'Laughing',
#        'Sitting', 'Speaking_Phone', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Sitting', 'Sitting', 'Speaking',
#        'Sitting', 'Using_Phone', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Sitting', 'Sitting',
#        'Using_Phone', 'Using_Phone', 'Speaking', 'Speaking_Phone',
#        'Speaking', 'Speaking_Phone', 'Laughing', 'Sitting',
#        'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone', 'Laughing',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Speaking', 'Using_Phone', 'Sitting',
#        'Using_Phone', 'Using_Phone', 'Laughing', 'Using_Phone', 'Sitting',
#        'Using_Phone', 'Speaking', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Laughing', 'Laughing', 'Using_Phone',
#        'Using_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking_Phone', 'Sitting', 'Sitting', 'Using_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking', 'Sitting',
#        'Speaking_Phone', 'Using_Phone', 'Speaking_Phone', 'Sitting',
#        'Sitting', 'Laughing', 'Speaking', 'Sitting', 'Using_Phone',
#        'Sitting', 'Speaking', 'Speaking', 'Sitting', 'Sitting',
#        'Laughing', 'Speaking', 'Speaking_Phone', 'Laughing',
#        'Using_Phone', 'Using_Phone', 'Sitting', 'Using_Phone', 'Sitting',
#        'Speaking_Phone', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Speaking', 'Using_Phone', 'Speaking', 'Sitting', 'Sitting',
#        'Sitting', 'Laughing', 'Sitting', 'Using_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Speaking', 'Sitting', 'Sitting',
#        'Laughing', 'Sitting', 'Laughing', 'Laughing', 'Laughing',
#        'Sitting', 'Using_Phone', 'Sitting', 'Using_Phone', 'Speaking',
#        'Speaking_Phone', 'Speaking', 'Speaking_Phone', 'Using_Phone',
#        'Sitting', 'Speaking', 'Laughing', 'Speaking_Phone', 'Using_Phone',
#        'Using_Phone', 'Speaking', 'Using_Phone', 'Speaking', 'Laughing',
#        'Laughing', 'Sitting', 'Sitting', 'Speaking_Phone', 'Laughing',
#        'Speaking', 'Speaking_Phone', 'Speaking_Phone', 'Speaking_Phone',
#        'Using_Phone', 'Speaking_Phone', 'Speaking_Phone', 'Sitting',
#        'Laughing', 'Sitting', 'Laughing', 'Using_Phone', 'Speaking_Phone'],
#       dtype=object)

# %%
y_test
# Out:
# 463     Speaking_Phone
# 1868          Speaking
# 1538           Sitting
# 422     Speaking_Phone
# 1016       Using_Phone
#              ...
# 147           Laughing
# 1410           Sitting
# 227           Laughing
# 1185       Using_Phone
# 485     Speaking_Phone
# Name: class, Length: 591, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.91 0.   0.02 0.05 0.02]
# Laughing [0.91 0.   0.01 0.06 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.9  0.   0.04 0.04 0.02]
# Laughing [0.86 0.   0.06 0.06 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.01 0.05 0.02]
# Laughing [0.92 0.   0.01 0.05 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.81 0.   0.07 0.1  0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.8  0.   0.08 0.1  0.02]
# Laughing [0.8  0.   0.08 0.1  0.02]
# Laughing [0.81 0.   0.09 0.08 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# Laughing [0.92 0.   0.02 0.04 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.93 0.   0.02 0.03 0.02]
# Laughing [0.94 0.   0.03 0.02 0.01]
# Laughing [0.94 0.   0.01 0.04 0.01]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.95 0.   0.03 0.01 0.01]
# Laughing [0.95 0.   0.03 0.01 0.01]
# Laughing [0.95 0.   0.03 0.01 0.01]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.96 0.   0.02 0.01 0.01]
# Laughing [0.99 0.   0.   0.   0.01]
# Laughing [1. 0. 0. 0. 0.]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [1. 0. 0. 0. 0.]
# Laughing [1. 0. 0. 0. 0.]
# Laughing [1. 0. 0. 0. 0.]
# Laughing [1. 0. 0. 0. 0.]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [1. 0. 0. 0. 0.]
# Laughing [1. 0. 0. 0. 0.]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [1. 0. 0. 0. 0.]
# Laughing [1. 0. 0. 0. 0.]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.99 0.   0.   0.   0.01]
# Laughing [0.98 0.   0.   0.01 0.01]
# Laughing [0.98 0.   0.   0.01 0.01]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.98 0.   0.   0.01 0.01]
# Laughing [0.86 0.   0.06 0.06 0.02]
# Laughing [0.71 0.   0.15 0.11 0.03]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.7  0.   0.15 0.12 0.03]
# Laughing [0.69 0.   0.16 0.12 0.03]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.4  0.   0.22 0.34 0.04]
# Speaking_Phone [0.25 0.   0.35 0.38 0.02]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.15 0.   0.38 0.43 0.04]
# Speaking_Phone [0.23 0.   0.33 0.38 0.06]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.15 0.01 0.35 0.38 0.11]
# Laughing [0.45 0.   0.27 0.19 0.09]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.36 0.   0.3  0.31 0.03]
# Laughing [0.35 0.   0.31 0.31 0.03]
# Laughing [0.35 0.   0.35 0.23 0.07]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Using_Phone [0.01 0.27 0.24 0.02 0.46]
# Sitting [0.   0.35 0.31 0.03 0.31]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.02 0.26 0.4  0.06 0.26]
# Sitting [0.01 0.36 0.32 0.04 0.27]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.   0.19 0.58 0.15 0.08]
# Speaking [0.08 0.05 0.65 0.15 0.07]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.02 0.04 0.61 0.16 0.17]
# Speaking [0.03 0.03 0.66 0.14 0.14]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.05 0.02 0.42 0.36 0.15]
# Speaking_Phone [0.07 0.01 0.38 0.44 0.1 ]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.15 0.01 0.26 0.42 0.16]
# Speaking_Phone [0.18 0.01 0.29 0.33 0.19]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.18 0.02 0.28 0.36 0.16]
# Speaking_Phone [0.13 0.03 0.31 0.42 0.11]
# Speaking_Phone [0.13 0.03 0.29 0.45 0.1 ]
# Speaking_Phone [0.17 0.02 0.3  0.36 0.15]
# Speaking_Phone [0.15 0.02 0.3  0.37 0.16]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.26 0.01 0.36 0.25 0.12]
# Speaking_Phone [0.15 0.   0.25 0.34 0.26]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.13 0.01 0.28 0.33 0.25]
# Speaking_Phone [0.17 0.   0.26 0.33 0.24]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.27 0.01 0.17 0.37 0.18]
# Speaking_Phone [0.3  0.01 0.13 0.39 0.17]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.26 0.01 0.2  0.42 0.11]
# Speaking_Phone [0.23 0.01 0.2  0.4  0.16]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.26 0.01 0.18 0.38 0.17]
# Speaking_Phone [0.34 0.   0.14 0.43 0.09]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.23 0.   0.2  0.46 0.11]
# Speaking_Phone [0.19 0.   0.21 0.52 0.08]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.24 0.   0.22 0.34 0.2 ]
# Speaking_Phone [0.24 0.   0.17 0.4  0.19]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.26 0.   0.17 0.43 0.14]
# Speaking_Phone [0.24 0.   0.17 0.43 0.16]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.19 0.   0.2  0.4  0.21]
# Speaking_Phone [0.2  0.   0.19 0.44 0.17]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.22 0.   0.17 0.39 0.22]
# Speaking_Phone [0.21 0.   0.2  0.41 0.18]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.21 0.   0.2  0.4  0.19]
# Speaking_Phone [0.23 0.   0.16 0.43 0.18]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.27 0.   0.18 0.38 0.17]
# Speaking_Phone [0.25 0.   0.19 0.37 0.19]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.12 0.   0.22 0.47 0.19]
# Speaking_Phone [0.23 0.   0.21 0.38 0.18]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.11 0.   0.26 0.42 0.21]
# Speaking_Phone [0.11 0.   0.26 0.42 0.21]
# Speaking [0.09 0.   0.32 0.28 0.31]
# Laughing [0.34 0.   0.19 0.34 0.13]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.27 0.   0.25 0.32 0.16]
# Speaking_Phone [0.3  0.   0.26 0.32 0.12]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.17 0.   0.29 0.36 0.18]
# Speaking [0.16 0.   0.32 0.29 0.23]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.25 0.   0.21 0.36 0.18]
# Speaking [0.25 0.   0.26 0.25 0.24]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking_Phone [0.18 0.   0.29 0.31 0.22]
# ...
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.28 0.   0.38 0.22 0.12]
# Speaking [0.29 0.   0.37 0.22 0.12]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.23 0.   0.4  0.24 0.13]
# Speaking [0.3  0.   0.36 0.2  0.14]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.39 0.   0.32 0.19 0.1 ]
# Laughing [0.35 0.   0.35 0.21 0.09]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.28 0.   0.35 0.25 0.12]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.37 0.   0.31 0.23 0.09]
# Speaking [0.31 0.   0.32 0.24 0.13]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.37 0.   0.32 0.22 0.09]
# Laughing [0.36 0.   0.33 0.22 0.09]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.31 0.   0.37 0.24 0.08]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.33 0.   0.35 0.26 0.06]
# Laughing [0.43 0.   0.28 0.24 0.05]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.44 0.   0.29 0.21 0.06]
# Laughing [0.48 0.   0.25 0.22 0.05]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.49 0.   0.25 0.2  0.06]
# Laughing [0.44 0.   0.28 0.21 0.07]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.41 0.   0.24 0.25 0.1 ]
# Speaking [0.28 0.   0.34 0.28 0.1 ]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.35 0.   0.31 0.24 0.1 ]
# Laughing [0.4  0.   0.3  0.24 0.06]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.4  0.   0.29 0.24 0.07]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.35 0.   0.32 0.25 0.08]
# Laughing [0.35 0.   0.31 0.26 0.08]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.36 0.   0.3  0.26 0.08]
# Laughing [0.41 0.   0.29 0.22 0.08]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.39 0.   0.31 0.24 0.06]
# Laughing [0.38 0.   0.29 0.24 0.09]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.45 0.   0.28 0.2  0.07]
# Laughing [0.41 0.   0.27 0.24 0.08]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Speaking [0.31 0.   0.32 0.29 0.08]
# Laughing [0.32 0.   0.32 0.3  0.06]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.48 0.   0.22 0.25 0.05]
# Laughing [0.53 0.   0.23 0.21 0.03]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.48 0.   0.25 0.23 0.04]
# Laughing [0.43 0.   0.27 0.25 0.05]
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\koush\anaconda3\envs\main\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Laughing [0.48 0.   0.25 0.24 0.03]
# Laughing [0.37 0.   0.29 0.29 0.05]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
